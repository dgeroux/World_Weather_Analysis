# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

weather_key = "ed2c0576a83b31218566f5dc40101261"

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

lat_lngs

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 753

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hokitika
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | hasaki
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | tunoshna
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | sur
# Processing Record 16 of Set 1 | codrington
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | paamiut
# Processing Record 19 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | sorocaba
# Processing Record 22 of Set 1 | altamira
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | teofilo otoni
# Processing Record 25 of Set 1 | fare
# Processing Record 26 of Set 1 | guiratinga
# Processing Record 27 of Set 1 | khartoum
# Processing Record 28 of Set 1 | santa rosa
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | inirida
# Processing Record 32 of Set 1 | gazanjyk
# Processing Record 33 of Set 1 | megion
# Processing Record 34 of Set 1 | ahipara
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | strezhevoy
# Processing Record 41 of Set 1 | marawi
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | anloga
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | laguna
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | komsomolskiy
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | constantine
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | novorzhev
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | constitucion
# Processing Record 11 of Set 2 | nago
# Processing Record 12 of Set 2 | talnakh
# Processing Record 13 of Set 2 | merauke
# Processing Record 14 of Set 2 | lavrentiya
# Processing Record 15 of Set 2 | tura
# Processing Record 16 of Set 2 | lompoc
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | coquimbo
# Processing Record 20 of Set 2 | sao filipe
# Processing Record 21 of Set 2 | boundiali
# Processing Record 22 of Set 2 | jammalamadugu
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | cimarron hills
# Processing Record 25 of Set 2 | dharchula
# Processing Record 26 of Set 2 | sasciori
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | vernon
# Processing Record 29 of Set 2 | port-gentil
# Processing Record 30 of Set 2 | el alto
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | tiksi
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | byron bay
# Processing Record 35 of Set 2 | patnos
# Processing Record 36 of Set 2 | clyde river
# Processing Record 37 of Set 2 | vila franca do campo
# Processing Record 38 of Set 2 | mayo
# Processing Record 39 of Set 2 | madera
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | rafaela
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | rio claro
# Processing Record 44 of Set 2 | souillac
# Processing Record 45 of Set 2 | hamilton
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | kultuk
# Processing Record 48 of Set 2 | whakatane
# Processing Record 49 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 2 | tome-acu
# City not found. Skipping...
# Processing Record 1 of Set 3 | yerbogachen
# Processing Record 2 of Set 3 | port lincoln
# Processing Record 3 of Set 3 | sayyan
# Processing Record 4 of Set 3 | iberia
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | fairbanks
# Processing Record 7 of Set 3 | katherine
# Processing Record 8 of Set 3 | manokwari
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | ankang
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | mandera
# Processing Record 13 of Set 3 | bubaque
# Processing Record 14 of Set 3 | kimbe
# Processing Record 15 of Set 3 | bengkulu
# Processing Record 16 of Set 3 | soyo
# Processing Record 17 of Set 3 | ancud
# Processing Record 18 of Set 3 | asuncion
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | ust-shonosha
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | jeremoabo
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | conceicao do araguaia
# Processing Record 25 of Set 3 | college
# Processing Record 26 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 3 | kapaa
# Processing Record 28 of Set 3 | praia
# Processing Record 29 of Set 3 | katsuura
# Processing Record 30 of Set 3 | port blair
# Processing Record 31 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 3 | asau
# Processing Record 33 of Set 3 | mon
# Processing Record 34 of Set 3 | hofn
# Processing Record 35 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 3 | pevek
# Processing Record 37 of Set 3 | fulitun
# City not found. Skipping...
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | rocha
# Processing Record 40 of Set 3 | sakakah
# Processing Record 41 of Set 3 | chokurdakh
# Processing Record 42 of Set 3 | esna
# Processing Record 43 of Set 3 | hobart
# Processing Record 44 of Set 3 | vanimo
# Processing Record 45 of Set 3 | barao de melgaco
# Processing Record 46 of Set 3 | luwero
# Processing Record 47 of Set 3 | itarema
# Processing Record 48 of Set 3 | te anau
# Processing Record 49 of Set 3 | ginir
# Processing Record 50 of Set 3 | mar del plata
# Processing Record 1 of Set 4 | ponta delgada
# Processing Record 2 of Set 4 | hirara
# Processing Record 3 of Set 4 | hammerfest
# Processing Record 4 of Set 4 | srednekolymsk
# Processing Record 5 of Set 4 | gimli
# Processing Record 6 of Set 4 | bardiyah
# Processing Record 7 of Set 4 | lihula
# Processing Record 8 of Set 4 | lagoa
# Processing Record 9 of Set 4 | santa cruz de la palma
# Processing Record 10 of Set 4 | new norfolk
# Processing Record 11 of Set 4 | batagay
# Processing Record 12 of Set 4 | cuamba
# Processing Record 13 of Set 4 | magistralnyy
# Processing Record 14 of Set 4 | brae
# Processing Record 15 of Set 4 | kempsey
# Processing Record 16 of Set 4 | norman wells
# Processing Record 17 of Set 4 | ishigaki
# Processing Record 18 of Set 4 | arauco
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | elat
# Processing Record 21 of Set 4 | leningradskiy
# Processing Record 22 of Set 4 | kirsanov
# Processing Record 23 of Set 4 | vestmannaeyjar
# Processing Record 24 of Set 4 | san patricio
# Processing Record 25 of Set 4 | balabac
# Processing Record 26 of Set 4 | ribeira grande
# Processing Record 27 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 4 | keokuk
# Processing Record 29 of Set 4 | narsaq
# Processing Record 30 of Set 4 | selkirk
# Processing Record 31 of Set 4 | saldanha
# Processing Record 32 of Set 4 | kargasok
# Processing Record 33 of Set 4 | puerto baquerizo moreno
# Processing Record 34 of Set 4 | kensington
# Processing Record 35 of Set 4 | saint-augustin
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | ruthin
# Processing Record 38 of Set 4 | zhangye
# Processing Record 39 of Set 4 | acapulco
# Processing Record 40 of Set 4 | jamestown
# Processing Record 41 of Set 4 | wick
# Processing Record 42 of Set 4 | lexington
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | chajul
# Processing Record 45 of Set 4 | cayenne
# Processing Record 46 of Set 4 | sydney
# Processing Record 47 of Set 4 | mizdah
# Processing Record 48 of Set 4 | oyama
# Processing Record 49 of Set 4 | flinders
# Processing Record 50 of Set 4 | salinopolis
# Processing Record 1 of Set 5 | maxixe
# Processing Record 2 of Set 5 | pisco
# Processing Record 3 of Set 5 | bartlesville
# Processing Record 4 of Set 5 | hurricane
# Processing Record 5 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 5 | salo
# Processing Record 7 of Set 5 | benguela
# Processing Record 8 of Set 5 | krasnoselkup
# Processing Record 9 of Set 5 | mancio lima
# Processing Record 10 of Set 5 | coihaique
# Processing Record 11 of Set 5 | jutai
# Processing Record 12 of Set 5 | mackenzie
# Processing Record 13 of Set 5 | tuatapere
# Processing Record 14 of Set 5 | port hawkesbury
# Processing Record 15 of Set 5 | kampot
# Processing Record 16 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 5 | zyryanskoye
# Processing Record 18 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 5 | bahia honda
# Processing Record 20 of Set 5 | ulaanbaatar
# Processing Record 21 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 5 | salta
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | wasilla
# Processing Record 25 of Set 5 | bitung
# Processing Record 26 of Set 5 | saint-philippe
# Processing Record 27 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 5 | tucuma
# Processing Record 29 of Set 5 | mantua
# Processing Record 30 of Set 5 | quatre cocos
# Processing Record 31 of Set 5 | gadung
# Processing Record 32 of Set 5 | zhigansk
# Processing Record 33 of Set 5 | elk grove
# Processing Record 34 of Set 5 | qasigiannguit
# Processing Record 35 of Set 5 | neuquen
# Processing Record 36 of Set 5 | lorengau
# Processing Record 37 of Set 5 | west wendover
# Processing Record 38 of Set 5 | yakeshi
# Processing Record 39 of Set 5 | broome
# Processing Record 40 of Set 5 | linhares
# Processing Record 41 of Set 5 | sidi ali
# Processing Record 42 of Set 5 | christchurch
# Processing Record 43 of Set 5 | sterling
# Processing Record 44 of Set 5 | kurchum
# Processing Record 45 of Set 5 | mosquera
# Processing Record 46 of Set 5 | young
# Processing Record 47 of Set 5 | mvuma
# Processing Record 48 of Set 5 | comodoro rivadavia
# Processing Record 49 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 5 | goderich
# Processing Record 1 of Set 6 | ilulissat
# Processing Record 2 of Set 6 | bethel
# Processing Record 3 of Set 6 | salalah
# Processing Record 4 of Set 6 | belaya gora
# Processing Record 5 of Set 6 | sibolga
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | ust-koksa
# Processing Record 8 of Set 6 | acari
# Processing Record 9 of Set 6 | lincoln
# Processing Record 10 of Set 6 | trairi
# Processing Record 11 of Set 6 | karratha
# Processing Record 12 of Set 6 | vostok
# Processing Record 13 of Set 6 | hun
# Processing Record 14 of Set 6 | port hardy
# Processing Record 15 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 16 of Set 6 | noumea
# Processing Record 17 of Set 6 | kannur
# Processing Record 18 of Set 6 | liwale
# Processing Record 19 of Set 6 | karasjok
# Processing Record 20 of Set 6 | kayerkan
# Processing Record 21 of Set 6 | labe
# Processing Record 22 of Set 6 | aranos
# Processing Record 23 of Set 6 | fortuna
# Processing Record 24 of Set 6 | xining
# Processing Record 25 of Set 6 | filadelfia
# Processing Record 26 of Set 6 | bundaberg
# Processing Record 27 of Set 6 | shahreza
# Processing Record 28 of Set 6 | ola
# Processing Record 29 of Set 6 | storforshei
# Processing Record 30 of Set 6 | sijunjung
# Processing Record 31 of Set 6 | sola
# Processing Record 32 of Set 6 | klaksvik
# Processing Record 33 of Set 6 | half moon bay
# Processing Record 34 of Set 6 | peniche
# Processing Record 35 of Set 6 | esperance
# Processing Record 36 of Set 6 | bako
# Processing Record 37 of Set 6 | siocon
# Processing Record 38 of Set 6 | steinbach
# Processing Record 39 of Set 6 | candido mendes
# Processing Record 40 of Set 6 | aykhal
# Processing Record 41 of Set 6 | bolonchen
# City not found. Skipping...
# Processing Record 42 of Set 6 | tieli
# Processing Record 43 of Set 6 | hiji
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | isangel
# Processing Record 46 of Set 6 | meulaboh
# Processing Record 47 of Set 6 | bongandanga
# Processing Record 48 of Set 6 | smithers
# Processing Record 49 of Set 6 | carnarvon
# Processing Record 50 of Set 6 | toora-khem
# Processing Record 1 of Set 7 | abalak
# Processing Record 2 of Set 7 | torbay
# Processing Record 3 of Set 7 | presidencia roque saenz pena
# Processing Record 4 of Set 7 | margate
# Processing Record 5 of Set 7 | ranong
# Processing Record 6 of Set 7 | buala
# Processing Record 7 of Set 7 | kahului
# Processing Record 8 of Set 7 | lephepe
# City not found. Skipping...
# Processing Record 9 of Set 7 | durango
# Processing Record 10 of Set 7 | plettenberg bay
# Processing Record 11 of Set 7 | arkhara
# Processing Record 12 of Set 7 | puerto carreno
# Processing Record 13 of Set 7 | sokolo
# Processing Record 14 of Set 7 | lebu
# Processing Record 15 of Set 7 | southbridge
# Processing Record 16 of Set 7 | murgab
# Processing Record 17 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 7 | aksarka
# Processing Record 19 of Set 7 | valdivia
# Processing Record 20 of Set 7 | havelock
# Processing Record 21 of Set 7 | mandalgarh
# Processing Record 22 of Set 7 | airai
# Processing Record 23 of Set 7 | vryburg
# Processing Record 24 of Set 7 | husavik
# Processing Record 25 of Set 7 | sasovo
# Processing Record 26 of Set 7 | saskylakh
# Processing Record 27 of Set 7 | tibiri
# Processing Record 28 of Set 7 | pundaguitan
# Processing Record 29 of Set 7 | altay
# Processing Record 30 of Set 7 | jablanica
# Processing Record 31 of Set 7 | ruteng
# Processing Record 32 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 7 | moranbah
# Processing Record 34 of Set 7 | maridi
# Processing Record 35 of Set 7 | bathsheba
# Processing Record 36 of Set 7 | naryan-mar
# Processing Record 37 of Set 7 | kruisfontein
# Processing Record 38 of Set 7 | yumen
# Processing Record 39 of Set 7 | santander
# Processing Record 40 of Set 7 | tautira
# Processing Record 41 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 7 | carlos antonio lopez
# Processing Record 44 of Set 7 | yar-sale
# Processing Record 45 of Set 7 | bolama
# Processing Record 46 of Set 7 | puerto ayacucho
# Processing Record 47 of Set 7 | novouzensk
# Processing Record 48 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 7 | bilma
# Processing Record 50 of Set 7 | conakry
# Processing Record 1 of Set 8 | pemangkat
# Processing Record 2 of Set 8 | nara
# Processing Record 3 of Set 8 | kropotkin
# Processing Record 4 of Set 8 | dunedin
# Processing Record 5 of Set 8 | tigre
# Processing Record 6 of Set 8 | jumla
# Processing Record 7 of Set 8 | prokhorovka
# Processing Record 8 of Set 8 | maragogi
# Processing Record 9 of Set 8 | santa fe
# Processing Record 10 of Set 8 | humaita
# Processing Record 11 of Set 8 | miri
# Processing Record 12 of Set 8 | taoudenni
# Processing Record 13 of Set 8 | bhiwani
# Processing Record 14 of Set 8 | papara
# Processing Record 15 of Set 8 | inhambane
# Processing Record 16 of Set 8 | saint-marc-des-carrieres
# Processing Record 17 of Set 8 | oktyabrskoye
# Processing Record 18 of Set 8 | xingcheng
# Processing Record 19 of Set 8 | iturama
# Processing Record 20 of Set 8 | liverpool
# Processing Record 21 of Set 8 | muros
# Processing Record 22 of Set 8 | oktyabrskiy
# Processing Record 23 of Set 8 | bentiu
# Processing Record 24 of Set 8 | bull savanna
# Processing Record 25 of Set 8 | mount gambier
# Processing Record 26 of Set 8 | vila velha
# Processing Record 27 of Set 8 | verkhoyansk
# Processing Record 28 of Set 8 | padang
# Processing Record 29 of Set 8 | panjab
# Processing Record 30 of Set 8 | nelson bay
# Processing Record 31 of Set 8 | san sebastian
# Processing Record 32 of Set 8 | ketchikan
# Processing Record 33 of Set 8 | beringovskiy
# Processing Record 34 of Set 8 | podyuga
# Processing Record 35 of Set 8 | pimentel
# Processing Record 36 of Set 8 | varkaus
# Processing Record 37 of Set 8 | gogrial
# Processing Record 38 of Set 8 | tambacounda
# Processing Record 39 of Set 8 | huarmey
# Processing Record 40 of Set 8 | chimoio
# Processing Record 41 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 8 | misawa
# Processing Record 43 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 8 | baymak
# Processing Record 45 of Set 8 | san antonio
# Processing Record 46 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 47 of Set 8 | greensboro
# Processing Record 48 of Set 8 | veraval
# Processing Record 49 of Set 8 | moose factory
# Processing Record 50 of Set 8 | am timan
# Processing Record 1 of Set 9 | camocim
# Processing Record 2 of Set 9 | abu samrah
# Processing Record 3 of Set 9 | namibe
# Processing Record 4 of Set 9 | diego de almagro
# Processing Record 5 of Set 9 | fujin
# Processing Record 6 of Set 9 | puerto maldonado
# Processing Record 7 of Set 9 | rudkobing
# Processing Record 8 of Set 9 | takoradi
# Processing Record 9 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 9 | svetlyy
# Processing Record 11 of Set 9 | sept-iles
# Processing Record 12 of Set 9 | port moresby
# Processing Record 13 of Set 9 | booue
# Processing Record 14 of Set 9 | ambulu
# Processing Record 15 of Set 9 | darhan
# Processing Record 16 of Set 9 | nemuro
# Processing Record 17 of Set 9 | vao
# Processing Record 18 of Set 9 | tevaitoa
# Processing Record 19 of Set 9 | hvolsvollur
# Processing Record 20 of Set 9 | topchikha
# Processing Record 21 of Set 9 | kathu
# Processing Record 22 of Set 9 | correntina
# Processing Record 23 of Set 9 | mailag
# Processing Record 24 of Set 9 | bismarck
# Processing Record 25 of Set 9 | ho
# City not found. Skipping...
# Processing Record 26 of Set 9 | scarborough
# Processing Record 27 of Set 9 | port augusta
# Processing Record 28 of Set 9 | ende
# Processing Record 29 of Set 9 | kondinskoye
# Processing Record 30 of Set 9 | xingyi
# Processing Record 31 of Set 9 | kysyl-syr
# Processing Record 32 of Set 9 | ugoofaaru
# Processing Record 33 of Set 9 | avera
# Processing Record 34 of Set 9 | gambo
# Processing Record 35 of Set 9 | methoni
# Processing Record 36 of Set 9 | bud
# Processing Record 37 of Set 9 | la crosse
# Processing Record 38 of Set 9 | shimoda
# Processing Record 39 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 9 | oranjemund
# Processing Record 41 of Set 9 | penha
# Processing Record 42 of Set 9 | monywa
# Processing Record 43 of Set 9 | simeykyne
# Processing Record 44 of Set 9 | nishihara
# Processing Record 45 of Set 9 | sitka
# Processing Record 46 of Set 9 | punta alta
# Processing Record 47 of Set 9 | shenjiamen
# Processing Record 48 of Set 9 | grunstadt
# Processing Record 49 of Set 9 | oranjestad
# Processing Record 50 of Set 9 | vuktyl
# Processing Record 1 of Set 10 | floro
# Processing Record 2 of Set 10 | bambanglipuro
# Processing Record 3 of Set 10 | noyabrsk
# Processing Record 4 of Set 10 | saleilua
# City not found. Skipping...
# Processing Record 5 of Set 10 | elizabethton
# Processing Record 6 of Set 10 | banda aceh
# Processing Record 7 of Set 10 | boa vista
# Processing Record 8 of Set 10 | kostomuksha
# Processing Record 9 of Set 10 | raisinghnagar
# Processing Record 10 of Set 10 | sabang
# Processing Record 11 of Set 10 | belmonte
# Processing Record 12 of Set 10 | sivaki
# Processing Record 13 of Set 10 | kyzyl-suu
# Processing Record 14 of Set 10 | nizhniy odes
# Processing Record 15 of Set 10 | dzhebariki-khaya
# Processing Record 16 of Set 10 | caravelas
# Processing Record 17 of Set 10 | south lake tahoe
# Processing Record 18 of Set 10 | rawson
# Processing Record 19 of Set 10 | aklavik
# Processing Record 20 of Set 10 | kaliua
# Processing Record 21 of Set 10 | dera din panah
# City not found. Skipping...
# Processing Record 22 of Set 10 | afsin
# Processing Record 23 of Set 10 | juneau
# Processing Record 24 of Set 10 | beirut
# Processing Record 25 of Set 10 | nuuk
# Processing Record 26 of Set 10 | puerto escondido
# Processing Record 27 of Set 10 | sierpc
# Processing Record 28 of Set 10 | broken hill
# Processing Record 29 of Set 10 | tres arroyos
# Processing Record 30 of Set 10 | san javier
# Processing Record 31 of Set 10 | massena
# Processing Record 32 of Set 10 | gilgit
# Processing Record 33 of Set 10 | beloha
# Processing Record 34 of Set 10 | hovd
# Processing Record 35 of Set 10 | berlevag
# Processing Record 36 of Set 10 | florianopolis
# Processing Record 37 of Set 10 | les cayes
# Processing Record 38 of Set 10 | denpasar
# Processing Record 39 of Set 10 | sao jose da coroa grande
# Processing Record 40 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 10 | coaticook
# Processing Record 42 of Set 10 | port shepstone
# Processing Record 43 of Set 10 | samut prakan
# Processing Record 44 of Set 10 | yorosso
# Processing Record 45 of Set 10 | ermoupolis
# Processing Record 46 of Set 10 | manjakandriana
# Processing Record 47 of Set 10 | escarcega
# Processing Record 48 of Set 10 | faya
# Processing Record 49 of Set 10 | rabat
# Processing Record 50 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 11 | yankton
# Processing Record 2 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 3 of Set 11 | assiniboia
# Processing Record 4 of Set 11 | arzgir
# Processing Record 5 of Set 11 | tanout
# Processing Record 6 of Set 11 | lesnoy
# Processing Record 7 of Set 11 | pacific grove
# Processing Record 8 of Set 11 | cherskiy
# Processing Record 9 of Set 11 | labuhan
# Processing Record 10 of Set 11 | chimore
# Processing Record 11 of Set 11 | clermont
# Processing Record 12 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 13 of Set 11 | buraydah
# Processing Record 14 of Set 11 | batemans bay
# Processing Record 15 of Set 11 | madang
# Processing Record 16 of Set 11 | gushikawa
# Processing Record 17 of Set 11 | mokhsogollokh
# Processing Record 18 of Set 11 | digha
# Processing Record 19 of Set 11 | fuerte olimpo
# Processing Record 20 of Set 11 | matay
# Processing Record 21 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 22 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 11 | san juan
# Processing Record 24 of Set 11 | muli
# Processing Record 25 of Set 11 | shingu
# Processing Record 26 of Set 11 | ronne
# Processing Record 27 of Set 11 | atambua
# Processing Record 28 of Set 11 | nome
# Processing Record 29 of Set 11 | marzuq
# Processing Record 30 of Set 11 | pangnirtung
# Processing Record 31 of Set 11 | dudinka
# Processing Record 32 of Set 11 | tres picos
# Processing Record 33 of Set 11 | iwaki
# Processing Record 34 of Set 11 | cidreira
# Processing Record 35 of Set 11 | ludvika
# Processing Record 36 of Set 11 | palmeira
# Processing Record 37 of Set 11 | alihe
# Processing Record 38 of Set 11 | hellvik
# Processing Record 39 of Set 11 | kemijarvi
# Processing Record 40 of Set 11 | nouakchott
# Processing Record 41 of Set 11 | dingle
# Processing Record 42 of Set 11 | bayan
# Processing Record 43 of Set 11 | kaitangata
# Processing Record 44 of Set 11 | kalispell
# Processing Record 45 of Set 11 | san cristobal
# Processing Record 46 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 47 of Set 11 | lusaka
# Processing Record 48 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 11 | mnogovershinnyy
# Processing Record 50 of Set 11 | santa elena
# Processing Record 1 of Set 12 | las cruces
# Processing Record 2 of Set 12 | aquiraz
# Processing Record 3 of Set 12 | porto santo
# Processing Record 4 of Set 12 | mandalgovi
# Processing Record 5 of Set 12 | tomioka
# Processing Record 6 of Set 12 | balad
# Processing Record 7 of Set 12 | simian
# Processing Record 8 of Set 12 | rockhampton
# Processing Record 9 of Set 12 | marienburg
# Processing Record 10 of Set 12 | deyang
# Processing Record 11 of Set 12 | chara
# Processing Record 12 of Set 12 | camacha
# Processing Record 13 of Set 12 | cap malheureux
# Processing Record 14 of Set 12 | valparaiso
# Processing Record 15 of Set 12 | vila
# Processing Record 16 of Set 12 | axim
# Processing Record 17 of Set 12 | kawardha
# Processing Record 18 of Set 12 | cascais
# Processing Record 19 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 12 | muisne
# Processing Record 21 of Set 12 | lastoursville
# Processing Record 22 of Set 12 | yaan
# Processing Record 23 of Set 12 | satka
# Processing Record 24 of Set 12 | gravdal
# Processing Record 25 of Set 12 | victor harbor
# Processing Record 26 of Set 12 | egvekinot
# Processing Record 27 of Set 12 | willowmore
# Processing Record 28 of Set 12 | ziyamet
# City not found. Skipping...
# Processing Record 29 of Set 12 | aloleng
# Processing Record 30 of Set 12 | ahuimanu
# Processing Record 31 of Set 12 | warrnambool
# Processing Record 32 of Set 12 | dwarka
# Processing Record 33 of Set 12 | novaya bryan
# Processing Record 34 of Set 12 | challapata
# Processing Record 35 of Set 12 | merta
# Processing Record 36 of Set 12 | besikduzu
# Processing Record 37 of Set 12 | hualmay
# Processing Record 38 of Set 12 | hay river
# Processing Record 39 of Set 12 | san julian
# Processing Record 40 of Set 12 | athabasca
# Processing Record 41 of Set 12 | suhbaatar
# Processing Record 42 of Set 12 | opava
# Processing Record 43 of Set 12 | deputatskiy
# Processing Record 44 of Set 12 | vung tau
# Processing Record 45 of Set 12 | zhangjiakou
# Processing Record 46 of Set 12 | pilar
# Processing Record 47 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 12 | sisimiut
# Processing Record 49 of Set 12 | mehamn
# Processing Record 50 of Set 12 | zyryanka
# Processing Record 1 of Set 13 | menongue
# Processing Record 2 of Set 13 | lahat
# Processing Record 3 of Set 13 | bilibino
# Processing Record 4 of Set 13 | wanning
# Processing Record 5 of Set 13 | alta floresta
# Processing Record 6 of Set 13 | heilbron
# Processing Record 7 of Set 13 | urucara
# Processing Record 8 of Set 13 | san quintin
# Processing Record 9 of Set 13 | bonthe
# Processing Record 10 of Set 13 | namatanai
# Processing Record 11 of Set 13 | miram shah
# Processing Record 12 of Set 13 | paita
# Processing Record 13 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 13 | bida
# Processing Record 15 of Set 13 | anjangaon
# Processing Record 16 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 17 of Set 13 | andra
# Processing Record 18 of Set 13 | kuusamo
# Processing Record 19 of Set 13 | orlik
# Processing Record 20 of Set 13 | ballina
# Processing Record 21 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 22 of Set 13 | novyy urgal
# Processing Record 23 of Set 13 | korla
# Processing Record 24 of Set 13 | ulladulla
# Processing Record 25 of Set 13 | nouadhibou
# Processing Record 26 of Set 13 | ifanadiana
# Processing Record 27 of Set 13 | cabo san lucas
# Processing Record 28 of Set 13 | qaqortoq
# Processing Record 29 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 13 | bulgan
# Processing Record 31 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 13 | rapid valley
# Processing Record 34 of Set 13 | churapcha
# Processing Record 35 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 13 | makubetsu
# Processing Record 37 of Set 13 | reichenau
# Processing Record 38 of Set 13 | norton
# Processing Record 39 of Set 13 | maralal
# Processing Record 40 of Set 13 | basar
# Processing Record 41 of Set 13 | komsomolets
# Processing Record 42 of Set 13 | mezhdurechensk
# Processing Record 43 of Set 13 | tahe
# Processing Record 44 of Set 13 | rio gallegos
# Processing Record 45 of Set 13 | craig
# Processing Record 46 of Set 13 | sorland
# Processing Record 47 of Set 13 | adrar
# Processing Record 48 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 49 of Set 13 | malampaka
# Processing Record 50 of Set 13 | partenit
# Processing Record 1 of Set 14 | alyangula
# Processing Record 2 of Set 14 | atar
# Processing Record 3 of Set 14 | chalus
# Processing Record 4 of Set 14 | ayagoz
# Processing Record 5 of Set 14 | toguchin
# Processing Record 6 of Set 14 | xapuri
# Processing Record 7 of Set 14 | beisfjord
# Processing Record 8 of Set 14 | inndyr
# Processing Record 9 of Set 14 | corovode
# Processing Record 10 of Set 14 | ostrovnoy
# Processing Record 11 of Set 14 | lazaro cardenas
# Processing Record 12 of Set 14 | prince rupert
# Processing Record 13 of Set 14 | ribas do rio pardo
# Processing Record 14 of Set 14 | stornoway
# Processing Record 15 of Set 14 | leh
# Processing Record 16 of Set 14 | san andres
# Processing Record 17 of Set 14 | kalmar
# Processing Record 18 of Set 14 | wolow
# Processing Record 19 of Set 14 | palauig
# Processing Record 20 of Set 14 | osakarovka
# Processing Record 21 of Set 14 | kapit
# Processing Record 22 of Set 14 | faqirwali
# Processing Record 23 of Set 14 | las vegas
# Processing Record 24 of Set 14 | hambantota
# Processing Record 25 of Set 14 | hulan ergi
# Processing Record 26 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 27 of Set 14 | warrington
# Processing Record 28 of Set 14 | lashio
# Processing Record 29 of Set 14 | kikwit
# Processing Record 30 of Set 14 | ejura
# Processing Record 31 of Set 14 | lewistown
# Processing Record 32 of Set 14 | negele
# City not found. Skipping...
# Processing Record 33 of Set 14 | khandyga
# Processing Record 34 of Set 14 | kokopo
# Processing Record 35 of Set 14 | barra do garcas
# Processing Record 36 of Set 14 | aqtobe
# Processing Record 37 of Set 14 | nakamura
# Processing Record 38 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 14 | lisakovsk
# Processing Record 40 of Set 14 | poya
# Processing Record 41 of Set 14 | iskateley
# Processing Record 42 of Set 14 | yatou
# Processing Record 43 of Set 14 | rosarito
# Processing Record 44 of Set 14 | la primavera
# Processing Record 45 of Set 14 | maningrida
# Processing Record 46 of Set 14 | solnechnyy
# Processing Record 47 of Set 14 | bar
# Processing Record 48 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 49 of Set 14 | myitkyina
# Processing Record 50 of Set 14 | olafsvik
# Processing Record 1 of Set 15 | clonmel
# Processing Record 2 of Set 15 | buchanan
# Processing Record 3 of Set 15 | itaituba
# Processing Record 4 of Set 15 | gbarnga
# Processing Record 5 of Set 15 | pasni
# Processing Record 6 of Set 15 | corralillo
# Processing Record 7 of Set 15 | tezu
# Processing Record 8 of Set 15 | ekhabi
# Processing Record 9 of Set 15 | sechura
# Processing Record 10 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 11 of Set 15 | tayu
# Processing Record 12 of Set 15 | yanam
# Processing Record 13 of Set 15 | chester
# Processing Record 14 of Set 15 | halifax
# Processing Record 15 of Set 15 | marsh harbour
# Processing Record 16 of Set 15 | livezile
# Processing Record 17 of Set 15 | kirakira
# Processing Record 18 of Set 15 | kavaratti
# Processing Record 19 of Set 15 | ternate
# Processing Record 20 of Set 15 | lensk
# Processing Record 21 of Set 15 | redlands
# Processing Record 22 of Set 15 | haines junction
# Processing Record 23 of Set 15 | palmer
# Processing Record 24 of Set 15 | anadyr
# Processing Record 25 of Set 15 | wagar
# Processing Record 26 of Set 15 | toritama
# Processing Record 27 of Set 15 | alamos
# Processing Record 28 of Set 15 | jonkoping
# Processing Record 29 of Set 15 | kavaje
# Processing Record 30 of Set 15 | nizwa
# Processing Record 31 of Set 15 | oistins
# Processing Record 32 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 33 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 34 of Set 15 | minab
# Processing Record 35 of Set 15 | north bend
# Processing Record 36 of Set 15 | cutzamala
# City not found. Skipping...
# Processing Record 37 of Set 15 | umm kaddadah
# Processing Record 38 of Set 15 | panama city
# Processing Record 39 of Set 15 | saint-joseph
# Processing Record 40 of Set 15 | kamenka
# Processing Record 41 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 42 of Set 15 | shubarshi
# Processing Record 43 of Set 15 | tamsweg
# Processing Record 44 of Set 15 | ibra
# Processing Record 45 of Set 15 | ventspils
# Processing Record 46 of Set 15 | cserkeszolo
# Processing Record 47 of Set 15 | soyaltepec
# City not found. Skipping...
# Processing Record 48 of Set 15 | vestmanna
# Processing Record 49 of Set 15 | jiuquan
# Processing Record 50 of Set 15 | mayumba
# Processing Record 1 of Set 16 | qurayyat
# Processing Record 2 of Set 16 | marabba
# Processing Record 3 of Set 16 | kaura namoda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hokitika      NZ -42.7167  170.9667     61.05        75          69
# 1          Hilo      US  19.7297 -155.0900     91.27        77          75
# 2    Butaritari      KI   3.0707  172.7902     81.99        77          13
# 3        Hasaki      JP  35.7333  140.8333     61.29        56         100
# 4         Bluff      NZ -46.6000  168.3333     56.80        89         100
# 5      Tunoshna      RU  57.5459   40.1254     42.78        87         100
# 6        Albany      US  42.6001  -73.9662     61.45        31         100
# 7     Hithadhoo      MV  -0.6000   73.0833     80.19        86         100
# 8  Punta Arenas      CL -53.1500  -70.9167     42.91        81          40
# 9    Georgetown      MY   5.4112  100.3354     82.33        91          20
#
#    Wind Speed Current Description
# 0        1.43       broken clouds
# 1       11.50       broken clouds
# 2       18.92          few clouds
# 3       10.20     overcast clouds
# 4        5.19     overcast clouds
# 5        8.95     overcast clouds
# 6        1.01     overcast clouds
# 7       20.07       moderate rain
# 8       29.93          light rain
# 9        2.30          light rain

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
