# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 790

# %%
#Import dependencies
import requests
weather_key= "ed2c0576a83b31218566f5dc40101261"

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | san cristobal
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | komsomolskiy
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | palora
# Processing Record 7 of Set 1 | jaipur hat
# City not found. Skipping...
# Processing Record 8 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | tumaco
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | nicoya
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | constitucion
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 21 of Set 1 | pacific grove
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | port hedland
# Processing Record 24 of Set 1 | karratha
# Processing Record 25 of Set 1 | laguna
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | bauchi
# Processing Record 28 of Set 1 | sidi qasim
# City not found. Skipping...
# Processing Record 29 of Set 1 | general pico
# Processing Record 30 of Set 1 | san andres
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | kitimat
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | huarmey
# Processing Record 37 of Set 1 | eydhafushi
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | pahrump
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | leh
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | broken hill
# Processing Record 44 of Set 1 | ivanivka
# Processing Record 45 of Set 1 | sao filipe
# Processing Record 46 of Set 1 | saint george
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | balimo
# City not found. Skipping...
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | dunedin
# Processing Record 2 of Set 2 | andros town
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | tuatapere
# Processing Record 5 of Set 2 | hobyo
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | de aar
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | mazara del vallo
# Processing Record 10 of Set 2 | krasnozerskoye
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | dinguiraye
# Processing Record 13 of Set 2 | leo
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | griffith
# Processing Record 16 of Set 2 | nuevo laredo
# City not found. Skipping...
# Processing Record 17 of Set 2 | saint-georges
# Processing Record 18 of Set 2 | pangoa
# Processing Record 19 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | tazovskiy
# Processing Record 22 of Set 2 | lata
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | souris
# Processing Record 25 of Set 2 | caltanissetta
# Processing Record 26 of Set 2 | namibe
# Processing Record 27 of Set 2 | caraquet
# Processing Record 28 of Set 2 | burica
# City not found. Skipping...
# Processing Record 29 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 2 | makakilo city
# City not found. Skipping...
# Processing Record 31 of Set 2 | tukrah
# Processing Record 32 of Set 2 | clyde river
# Processing Record 33 of Set 2 | sept-iles
# Processing Record 34 of Set 2 | vestmannaeyjar
# Processing Record 35 of Set 2 | naze
# Processing Record 36 of Set 2 | katsuura
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | el retorno
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | fortuna
# Processing Record 41 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 2 | cabo san lucas
# Processing Record 43 of Set 2 | toora-khem
# Processing Record 44 of Set 2 | reyes
# Processing Record 45 of Set 2 | bay roberts
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | udachnyy
# Processing Record 48 of Set 2 | krasnoselkup
# Processing Record 49 of Set 2 | preston
# Processing Record 50 of Set 2 | guangyuan
# Processing Record 1 of Set 3 | cravinhos
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | nenjiang
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | talnakh
# Processing Record 7 of Set 3 | praia
# Processing Record 8 of Set 3 | portland
# Processing Record 9 of Set 3 | piedras negras
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 3 | havelock
# Processing Record 14 of Set 3 | ginir
# Processing Record 15 of Set 3 | manado
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | masvingo
# Processing Record 20 of Set 3 | salihorsk
# Processing Record 21 of Set 3 | kamaishi
# Processing Record 22 of Set 3 | tecoanapa
# Processing Record 23 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | beloha
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | arman
# Processing Record 28 of Set 3 | samba
# Processing Record 29 of Set 3 | marrakesh
# Processing Record 30 of Set 3 | noshiro
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | maceio
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | minsk
# Processing Record 35 of Set 3 | kavieng
# Processing Record 36 of Set 3 | fort nelson
# Processing Record 37 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 3 | chokurdakh
# Processing Record 39 of Set 3 | omagh
# Processing Record 40 of Set 3 | upernavik
# Processing Record 41 of Set 3 | bengkulu
# Processing Record 42 of Set 3 | nyurba
# Processing Record 43 of Set 3 | vila velha
# Processing Record 44 of Set 3 | pangody
# Processing Record 45 of Set 3 | vao
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | vathi
# Processing Record 48 of Set 3 | high level
# Processing Record 49 of Set 3 | puerto escondido
# Processing Record 50 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 4 | tammisaari
# Processing Record 2 of Set 4 | vuktyl
# Processing Record 3 of Set 4 | vardo
# Processing Record 4 of Set 4 | cienaga de flores
# City not found. Skipping...
# Processing Record 5 of Set 4 | kapaa
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | aban
# Processing Record 8 of Set 4 | george town
# Processing Record 9 of Set 4 | muhos
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | ajdabiya
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | jalu
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | khorramshahr
# Processing Record 17 of Set 4 | provideniya
# Processing Record 18 of Set 4 | airai
# Processing Record 19 of Set 4 | kjollefjord
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | grindavik
# Processing Record 22 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 4 | katherine
# Processing Record 24 of Set 4 | kakhovka
# Processing Record 25 of Set 4 | antiguo morelos
# Processing Record 26 of Set 4 | penco
# Processing Record 27 of Set 4 | sovetskiy
# Processing Record 28 of Set 4 | te anau
# Processing Record 29 of Set 4 | fairbanks
# Processing Record 30 of Set 4 | koson
# Processing Record 31 of Set 4 | cockburn town
# Processing Record 32 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 4 | huntington
# Processing Record 34 of Set 4 | codrington
# Processing Record 35 of Set 4 | hermanus
# Processing Record 36 of Set 4 | nesna
# Processing Record 37 of Set 4 | la asuncion
# Processing Record 38 of Set 4 | bogorodskoye
# Processing Record 39 of Set 4 | inuvik
# Processing Record 40 of Set 4 | hilo
# Processing Record 41 of Set 4 | general roca
# Processing Record 42 of Set 4 | oistins
# Processing Record 43 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 45 of Set 4 | hervey bay
# Processing Record 46 of Set 4 | iskateley
# Processing Record 47 of Set 4 | tal
# Processing Record 48 of Set 4 | saskylakh
# Processing Record 49 of Set 4 | kayerkan
# Processing Record 50 of Set 4 | dingle
# Processing Record 1 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 5 | muros
# Processing Record 3 of Set 5 | klaksvik
# Processing Record 4 of Set 5 | mazatan
# Processing Record 5 of Set 5 | bollnas
# Processing Record 6 of Set 5 | nouadhibou
# Processing Record 7 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 5 | mareeba
# Processing Record 9 of Set 5 | krasnomayskiy
# Processing Record 10 of Set 5 | muisne
# Processing Record 11 of Set 5 | aksarka
# Processing Record 12 of Set 5 | biltine
# Processing Record 13 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 5 | nanortalik
# Processing Record 15 of Set 5 | linguere
# Processing Record 16 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 5 | butaritari
# Processing Record 18 of Set 5 | bethel
# Processing Record 19 of Set 5 | praya
# Processing Record 20 of Set 5 | los llanos de aridane
# Processing Record 21 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 5 | jacareacanga
# Processing Record 23 of Set 5 | flin flon
# Processing Record 24 of Set 5 | la ronge
# Processing Record 25 of Set 5 | atlantis
# Processing Record 26 of Set 5 | tutoia
# Processing Record 27 of Set 5 | olinda
# Processing Record 28 of Set 5 | ortega
# Processing Record 29 of Set 5 | adre
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | pagudpud
# Processing Record 32 of Set 5 | bathsheba
# Processing Record 33 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 5 | longyearbyen
# Processing Record 35 of Set 5 | port hawkesbury
# Processing Record 36 of Set 5 | bambous virieux
# Processing Record 37 of Set 5 | gobabis
# Processing Record 38 of Set 5 | shubarkuduk
# Processing Record 39 of Set 5 | kupino
# Processing Record 40 of Set 5 | quchan
# Processing Record 41 of Set 5 | botou
# Processing Record 42 of Set 5 | itarema
# Processing Record 43 of Set 5 | mount pleasant
# Processing Record 44 of Set 5 | morden
# Processing Record 45 of Set 5 | lamu
# Processing Record 46 of Set 5 | quatre cocos
# Processing Record 47 of Set 5 | copiapo
# Processing Record 48 of Set 5 | vila franca do campo
# Processing Record 49 of Set 5 | elvas
# Processing Record 50 of Set 5 | saint-francois
# Processing Record 1 of Set 6 | kaeo
# Processing Record 2 of Set 6 | barra do garcas
# Processing Record 3 of Set 6 | bogande
# Processing Record 4 of Set 6 | avera
# Processing Record 5 of Set 6 | balkhash
# Processing Record 6 of Set 6 | simbahan
# Processing Record 7 of Set 6 | torbay
# Processing Record 8 of Set 6 | pisco
# Processing Record 9 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 10 of Set 6 | umm lajj
# Processing Record 11 of Set 6 | skjervoy
# Processing Record 12 of Set 6 | vrangel
# Processing Record 13 of Set 6 | itoman
# Processing Record 14 of Set 6 | erenhot
# Processing Record 15 of Set 6 | gazanjyk
# Processing Record 16 of Set 6 | buchanan
# Processing Record 17 of Set 6 | yuksekova
# Processing Record 18 of Set 6 | alyangula
# Processing Record 19 of Set 6 | poum
# Processing Record 20 of Set 6 | malumfashi
# Processing Record 21 of Set 6 | chuy
# Processing Record 22 of Set 6 | waipawa
# Processing Record 23 of Set 6 | faanui
# Processing Record 24 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 25 of Set 6 | surt
# Processing Record 26 of Set 6 | boa vista
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | nadym
# Processing Record 29 of Set 6 | yerbogachen
# Processing Record 30 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 6 | pizarro
# Processing Record 32 of Set 6 | gerede
# Processing Record 33 of Set 6 | sinazongwe
# Processing Record 34 of Set 6 | yar-sale
# Processing Record 35 of Set 6 | beisfjord
# Processing Record 36 of Set 6 | huron
# Processing Record 37 of Set 6 | coquimbo
# Processing Record 38 of Set 6 | banjarmasin
# Processing Record 39 of Set 6 | amuntai
# Processing Record 40 of Set 6 | ukiah
# Processing Record 41 of Set 6 | conde
# Processing Record 42 of Set 6 | nome
# Processing Record 43 of Set 6 | emerald
# Processing Record 44 of Set 6 | akdagmadeni
# Processing Record 45 of Set 6 | desur
# Processing Record 46 of Set 6 | turayf
# Processing Record 47 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 6 | durban
# Processing Record 49 of Set 6 | krasnoborsk
# Processing Record 50 of Set 6 | pierre
# Processing Record 1 of Set 7 | tartus
# Processing Record 2 of Set 7 | mtambile
# Processing Record 3 of Set 7 | khandyga
# Processing Record 4 of Set 7 | necochea
# Processing Record 5 of Set 7 | san pedro
# Processing Record 6 of Set 7 | baghmara
# Processing Record 7 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 7 | linxia
# Processing Record 9 of Set 7 | port hardy
# Processing Record 10 of Set 7 | waingapu
# Processing Record 11 of Set 7 | valleyview
# Processing Record 12 of Set 7 | boddam
# Processing Record 13 of Set 7 | vokhtoga
# Processing Record 14 of Set 7 | kholodnyy
# Processing Record 15 of Set 7 | crotone
# Processing Record 16 of Set 7 | the valley
# Processing Record 17 of Set 7 | zeerust
# Processing Record 18 of Set 7 | meulaboh
# Processing Record 19 of Set 7 | qaqortoq
# Processing Record 20 of Set 7 | alofi
# Processing Record 21 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 7 | ningxiang
# Processing Record 24 of Set 7 | sandwick
# Processing Record 25 of Set 7 | kieta
# Processing Record 26 of Set 7 | tabou
# Processing Record 27 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 7 | kysyl-syr
# Processing Record 30 of Set 7 | westport
# Processing Record 31 of Set 7 | svetlyy
# Processing Record 32 of Set 7 | sozopolis
# City not found. Skipping...
# Processing Record 33 of Set 7 | dhidhdhoo
# Processing Record 34 of Set 7 | ouro preto do oeste
# Processing Record 35 of Set 7 | tlahualilo
# City not found. Skipping...
# Processing Record 36 of Set 7 | lavrentiya
# Processing Record 37 of Set 7 | ahipara
# Processing Record 38 of Set 7 | victoria
# Processing Record 39 of Set 7 | hangu
# Processing Record 40 of Set 7 | ulaangom
# Processing Record 41 of Set 7 | lagoa
# Processing Record 42 of Set 7 | jeremie
# Processing Record 43 of Set 7 | aklavik
# Processing Record 44 of Set 7 | paita
# Processing Record 45 of Set 7 | hay river
# Processing Record 46 of Set 7 | rosita
# Processing Record 47 of Set 7 | ionia
# Processing Record 48 of Set 7 | norman wells
# Processing Record 49 of Set 7 | chernenko
# Processing Record 50 of Set 7 | havre-saint-pierre
# Processing Record 1 of Set 8 | ampanihy
# Processing Record 2 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 3 of Set 8 | nabire
# Processing Record 4 of Set 8 | beidao
# Processing Record 5 of Set 8 | yamada
# Processing Record 6 of Set 8 | warrington
# Processing Record 7 of Set 8 | padang
# Processing Record 8 of Set 8 | praia da vitoria
# Processing Record 9 of Set 8 | kendari
# Processing Record 10 of Set 8 | shikhazany
# Processing Record 11 of Set 8 | dicabisagan
# Processing Record 12 of Set 8 | tchollire
# Processing Record 13 of Set 8 | chapada dos guimaraes
# Processing Record 14 of Set 8 | ucluelet
# Processing Record 15 of Set 8 | olafsvik
# Processing Record 16 of Set 8 | agua verde
# Processing Record 17 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 8 | sidi ali
# Processing Record 19 of Set 8 | hualmay
# Processing Record 20 of Set 8 | ewa beach
# Processing Record 21 of Set 8 | aktau
# Processing Record 22 of Set 8 | rocha
# Processing Record 23 of Set 8 | harper
# Processing Record 24 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 8 | ibirama
# Processing Record 26 of Set 8 | tabas
# Processing Record 27 of Set 8 | murgab
# Processing Record 28 of Set 8 | nishihara
# Processing Record 29 of Set 8 | lorengau
# Processing Record 30 of Set 8 | luderitz
# Processing Record 31 of Set 8 | kaniama
# Processing Record 32 of Set 8 | eyl
# Processing Record 33 of Set 8 | leshukonskoye
# Processing Record 34 of Set 8 | nerang
# Processing Record 35 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 8 | buritis
# Processing Record 37 of Set 8 | port blair
# Processing Record 38 of Set 8 | winnemucca
# Processing Record 39 of Set 8 | karakulino
# Processing Record 40 of Set 8 | daru
# Processing Record 41 of Set 8 | havoysund
# Processing Record 42 of Set 8 | broome
# Processing Record 43 of Set 8 | severnoye
# Processing Record 44 of Set 8 | manono
# Processing Record 45 of Set 8 | paidha
# Processing Record 46 of Set 8 | port moresby
# Processing Record 47 of Set 8 | fukue
# Processing Record 48 of Set 8 | mikuni
# Processing Record 49 of Set 8 | tokat
# Processing Record 50 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 9 | imeni poliny osipenko
# Processing Record 2 of Set 9 | sioux lookout
# Processing Record 3 of Set 9 | yumen
# Processing Record 4 of Set 9 | terrasini
# Processing Record 5 of Set 9 | salalah
# Processing Record 6 of Set 9 | kasempa
# Processing Record 7 of Set 9 | mount isa
# Processing Record 8 of Set 9 | sitka
# Processing Record 9 of Set 9 | brae
# Processing Record 10 of Set 9 | hailar
# Processing Record 11 of Set 9 | sao desiderio
# Processing Record 12 of Set 9 | tocopilla
# Processing Record 13 of Set 9 | kalachinsk
# Processing Record 14 of Set 9 | alvaro obregon
# Processing Record 15 of Set 9 | paranapanema
# Processing Record 16 of Set 9 | kodiak
# Processing Record 17 of Set 9 | mayumba
# Processing Record 18 of Set 9 | tautira
# Processing Record 19 of Set 9 | cabedelo
# Processing Record 20 of Set 9 | hamilton
# Processing Record 21 of Set 9 | tari
# Processing Record 22 of Set 9 | bourail
# Processing Record 23 of Set 9 | sanary-sur-mer
# Processing Record 24 of Set 9 | conakry
# Processing Record 25 of Set 9 | atasu
# Processing Record 26 of Set 9 | inveraray
# City not found. Skipping...
# Processing Record 27 of Set 9 | tracy
# Processing Record 28 of Set 9 | chernyshevskiy
# Processing Record 29 of Set 9 | aykhal
# Processing Record 30 of Set 9 | baglung
# Processing Record 31 of Set 9 | henties bay
# Processing Record 32 of Set 9 | umea
# Processing Record 33 of Set 9 | vanavara
# Processing Record 34 of Set 9 | walvis bay
# Processing Record 35 of Set 9 | kawalu
# Processing Record 36 of Set 9 | asau
# Processing Record 37 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 9 | lons
# Processing Record 39 of Set 9 | shancheng
# Processing Record 40 of Set 9 | ensley
# Processing Record 41 of Set 9 | sorland
# Processing Record 42 of Set 9 | sangmelima
# Processing Record 43 of Set 9 | esperance
# Processing Record 44 of Set 9 | samarai
# Processing Record 45 of Set 9 | chipinge
# Processing Record 46 of Set 9 | samandag
# Processing Record 47 of Set 9 | haines junction
# Processing Record 48 of Set 9 | silopi
# Processing Record 49 of Set 9 | hinton
# Processing Record 50 of Set 9 | pastavy
# Processing Record 1 of Set 10 | lulea
# Processing Record 2 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 3 of Set 10 | marabba
# Processing Record 4 of Set 10 | kajaani
# Processing Record 5 of Set 10 | amazar
# Processing Record 6 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 7 of Set 10 | college
# Processing Record 8 of Set 10 | villiers
# Processing Record 9 of Set 10 | lavumisa
# Processing Record 10 of Set 10 | ancud
# Processing Record 11 of Set 10 | nzerekore
# Processing Record 12 of Set 10 | sisimiut
# Processing Record 13 of Set 10 | hami
# Processing Record 14 of Set 10 | paraiso
# Processing Record 15 of Set 10 | ambilobe
# Processing Record 16 of Set 10 | shenjiamen
# Processing Record 17 of Set 10 | kinsale
# Processing Record 18 of Set 10 | aljezur
# Processing Record 19 of Set 10 | hambantota
# Processing Record 20 of Set 10 | leningradskiy
# Processing Record 21 of Set 10 | marawi
# Processing Record 22 of Set 10 | zykovo
# Processing Record 23 of Set 10 | palestine
# Processing Record 24 of Set 10 | mackay
# Processing Record 25 of Set 10 | khani
# Processing Record 26 of Set 10 | pangkalanbuun
# Processing Record 27 of Set 10 | enshi
# Processing Record 28 of Set 10 | nanchang
# Processing Record 29 of Set 10 | pochutla
# Processing Record 30 of Set 10 | wamba
# Processing Record 31 of Set 10 | bilibino
# Processing Record 32 of Set 10 | qui nhon
# Processing Record 33 of Set 10 | kui buri
# Processing Record 34 of Set 10 | bako
# Processing Record 35 of Set 10 | mahebourg
# Processing Record 36 of Set 10 | north bend
# Processing Record 37 of Set 10 | seoul
# Processing Record 38 of Set 10 | shimanovsk
# Processing Record 39 of Set 10 | pimenteiras
# Processing Record 40 of Set 10 | kindu
# Processing Record 41 of Set 10 | murshidabad
# Processing Record 42 of Set 10 | ulladulla
# Processing Record 43 of Set 10 | chibombo
# Processing Record 44 of Set 10 | porto novo
# Processing Record 45 of Set 10 | port-cartier
# Processing Record 46 of Set 10 | booue
# Processing Record 47 of Set 10 | javanrud
# Processing Record 48 of Set 10 | saint-louis
# Processing Record 49 of Set 10 | kintampo
# Processing Record 50 of Set 10 | omboue
# Processing Record 1 of Set 11 | srednekolymsk
# Processing Record 2 of Set 11 | hattiesburg
# Processing Record 3 of Set 11 | pinega
# Processing Record 4 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 5 of Set 11 | lajeado
# Processing Record 6 of Set 11 | santa maria
# Processing Record 7 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 8 of Set 11 | akyab
# Processing Record 9 of Set 11 | bethlehem
# Processing Record 10 of Set 11 | ketou
# Processing Record 11 of Set 11 | sibolga
# Processing Record 12 of Set 11 | angra dos reis
# Processing Record 13 of Set 11 | christchurch
# Processing Record 14 of Set 11 | usinsk
# Processing Record 15 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 16 of Set 11 | akureyri
# Processing Record 17 of Set 11 | margate
# Processing Record 18 of Set 11 | saint-pierre
# Processing Record 19 of Set 11 | aswan
# Processing Record 20 of Set 11 | ambon
# Processing Record 21 of Set 11 | lafiagi
# Processing Record 22 of Set 11 | bang saphan
# Processing Record 23 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 11 | puerto concordia
# Processing Record 25 of Set 11 | maragogi
# Processing Record 26 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 11 | lokachi
# Processing Record 28 of Set 11 | kattivakkam
# Processing Record 29 of Set 11 | bara
# Processing Record 30 of Set 11 | beringovskiy
# Processing Record 31 of Set 11 | pangnirtung
# Processing Record 32 of Set 11 | churapcha
# Processing Record 33 of Set 11 | tupiza
# Processing Record 34 of Set 11 | luau
# Processing Record 35 of Set 11 | isangel
# Processing Record 36 of Set 11 | barstow
# Processing Record 37 of Set 11 | yeppoon
# Processing Record 38 of Set 11 | charleston
# Processing Record 39 of Set 11 | clarence town
# Processing Record 40 of Set 11 | mbanza-ngungu
# Processing Record 41 of Set 11 | rosario
# Processing Record 42 of Set 11 | lakatoro
# Processing Record 43 of Set 11 | hofn
# Processing Record 44 of Set 11 | sao luis
# Processing Record 45 of Set 11 | jimo
# Processing Record 46 of Set 11 | touros
# Processing Record 47 of Set 11 | am timan
# Processing Record 48 of Set 11 | charters towers
# Processing Record 49 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 11 | road town
# Processing Record 1 of Set 12 | chake chake
# Processing Record 2 of Set 12 | freeport
# Processing Record 3 of Set 12 | taltal
# Processing Record 4 of Set 12 | trelew
# Processing Record 5 of Set 12 | hede
# Processing Record 6 of Set 12 | zelenoborskiy
# Processing Record 7 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 12 | talcahuano
# Processing Record 9 of Set 12 | contamana
# Processing Record 10 of Set 12 | wladyslawowo
# Processing Record 11 of Set 12 | filingue
# Processing Record 12 of Set 12 | berlin
# Processing Record 13 of Set 12 | milkovo
# Processing Record 14 of Set 12 | derzhavinsk
# Processing Record 15 of Set 12 | olbia
# Processing Record 16 of Set 12 | hays
# Processing Record 17 of Set 12 | villazon
# Processing Record 18 of Set 12 | lere
# Processing Record 19 of Set 12 | maningrida
# Processing Record 20 of Set 12 | riyadh
# Processing Record 21 of Set 12 | lensk
# Processing Record 22 of Set 12 | clarksburg
# Processing Record 23 of Set 12 | pasni
# Processing Record 24 of Set 12 | sredec
# City not found. Skipping...
# Processing Record 25 of Set 12 | casambalangan
# Processing Record 26 of Set 12 | gari
# Processing Record 27 of Set 12 | mezhdurechenskiy
# Processing Record 28 of Set 12 | danilovka
# Processing Record 29 of Set 12 | tshela
# Processing Record 30 of Set 12 | mehamn
# Processing Record 31 of Set 12 | qazvin
# Processing Record 32 of Set 12 | sur
# Processing Record 33 of Set 12 | kavaratti
# Processing Record 34 of Set 12 | turukhansk
# Processing Record 35 of Set 12 | berlevag
# Processing Record 36 of Set 12 | sola
# Processing Record 37 of Set 12 | ipilan
# Processing Record 38 of Set 12 | egvekinot
# Processing Record 39 of Set 12 | ingraj bazar
# Processing Record 40 of Set 12 | bataipora
# Processing Record 41 of Set 12 | santa cruz
# Processing Record 42 of Set 12 | sijunjung
# Processing Record 43 of Set 12 | la rioja
# Processing Record 44 of Set 12 | chiredzi
# Processing Record 45 of Set 12 | manzhouli
# Processing Record 46 of Set 12 | namie
# Processing Record 47 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 12 | ayan
# Processing Record 49 of Set 12 | san rafael
# Processing Record 50 of Set 12 | schijndel
# Processing Record 1 of Set 13 | mahanoro
# Processing Record 2 of Set 13 | zhezkazgan
# Processing Record 3 of Set 13 | biak
# Processing Record 4 of Set 13 | yuzhou
# Processing Record 5 of Set 13 | sao joao da barra
# Processing Record 6 of Set 13 | inirida
# Processing Record 7 of Set 13 | cuamba
# Processing Record 8 of Set 13 | bouillante
# Processing Record 9 of Set 13 | labuhan
# Processing Record 10 of Set 13 | bereda
# Processing Record 11 of Set 13 | moose factory
# Processing Record 12 of Set 13 | jutai
# Processing Record 13 of Set 13 | bowen
# Processing Record 14 of Set 13 | arizona
# Processing Record 15 of Set 13 | mahibadhoo
# Processing Record 16 of Set 13 | mpika
# Processing Record 17 of Set 13 | zhangjiakou
# Processing Record 18 of Set 13 | linkoping
# Processing Record 19 of Set 13 | manggar
# Processing Record 20 of Set 13 | urdoma
# Processing Record 21 of Set 13 | grand gaube
# Processing Record 22 of Set 13 | painesville
# Processing Record 23 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 13 | tezu
# Processing Record 26 of Set 13 | sulangan
# Processing Record 27 of Set 13 | arraial do cabo
# Processing Record 28 of Set 13 | nipawin
# Processing Record 29 of Set 13 | dolores
# Processing Record 30 of Set 13 | hurricane
# Processing Record 31 of Set 13 | guerrero negro
# Processing Record 32 of Set 13 | samus
# Processing Record 33 of Set 13 | port lincoln
# Processing Record 34 of Set 13 | lichuan
# Processing Record 35 of Set 13 | scarborough
# Processing Record 36 of Set 13 | simoes
# Processing Record 37 of Set 13 | lithgow
# Processing Record 38 of Set 13 | losone
# Processing Record 39 of Set 13 | micheweni
# Processing Record 40 of Set 13 | kathmandu
# Processing Record 41 of Set 13 | dubbo
# Processing Record 42 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 43 of Set 13 | rawson
# Processing Record 44 of Set 13 | mzimba
# Processing Record 45 of Set 13 | mbandaka
# Processing Record 46 of Set 13 | balkanabat
# Processing Record 47 of Set 13 | saint-augustin
# Processing Record 48 of Set 13 | kharp
# Processing Record 49 of Set 13 | nioro
# Processing Record 50 of Set 13 | sapa
# Processing Record 1 of Set 14 | flinders
# Processing Record 2 of Set 14 | anolaima
# Processing Record 3 of Set 14 | ialibu
# Processing Record 4 of Set 14 | nakasongola
# Processing Record 5 of Set 14 | finschhafen
# Processing Record 6 of Set 14 | mascota
# Processing Record 7 of Set 14 | alice springs
# Processing Record 8 of Set 14 | merauke
# Processing Record 9 of Set 14 | takoradi
# Processing Record 10 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 14 | amol
# Processing Record 12 of Set 14 | dimbokro
# Processing Record 13 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 14 | orje
# Processing Record 15 of Set 14 | mwene-ditu
# Processing Record 16 of Set 14 | svobodnyy
# Processing Record 17 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 14 | nehe
# Processing Record 19 of Set 14 | markova
# Processing Record 20 of Set 14 | watsa
# Processing Record 21 of Set 14 | nevel
# Processing Record 22 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 23 of Set 14 | tokur
# Processing Record 24 of Set 14 | kahului
# Processing Record 25 of Set 14 | aksu
# Processing Record 26 of Set 14 | padilla
# Processing Record 27 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 28 of Set 14 | bengkalis
# City not found. Skipping...
# Processing Record 29 of Set 14 | bulgan
# Processing Record 30 of Set 14 | kushmurun
# Processing Record 31 of Set 14 | presidente prudente
# Processing Record 32 of Set 14 | mayo
# Processing Record 33 of Set 14 | synya
# Processing Record 34 of Set 14 | anakapalle
# Processing Record 35 of Set 14 | yerofey pavlovich
# Processing Record 36 of Set 14 | soyo
# Processing Record 37 of Set 14 | damghan
# Processing Record 38 of Set 14 | yulara
# Processing Record 39 of Set 14 | jasper
# Processing Record 40 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 41 of Set 14 | saraland
# Processing Record 42 of Set 14 | krusevac
# Processing Record 43 of Set 14 | vidim
# Processing Record 44 of Set 14 | comodoro rivadavia
# Processing Record 45 of Set 14 | balaipungut
# Processing Record 46 of Set 14 | naryan-mar
# Processing Record 47 of Set 14 | inhambane
# Processing Record 48 of Set 14 | iwaki
# Processing Record 49 of Set 14 | klyuchi
# Processing Record 50 of Set 14 | saint-die
# City not found. Skipping...
# Processing Record 1 of Set 15 | palmer
# Processing Record 2 of Set 15 | prince rupert
# Processing Record 3 of Set 15 | darhan
# Processing Record 4 of Set 15 | evensk
# Processing Record 5 of Set 15 | husavik
# Processing Record 6 of Set 15 | callaway
# Processing Record 7 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 15 | tingo maria
# Processing Record 9 of Set 15 | bairiki
# Processing Record 10 of Set 15 | bowmore
# Processing Record 11 of Set 15 | arkhangelskoye
# Processing Record 12 of Set 15 | ballina
# Processing Record 13 of Set 15 | farafangana
# Processing Record 14 of Set 15 | bacolod
# Processing Record 15 of Set 15 | acajutla
# Processing Record 16 of Set 15 | mobaye
# Processing Record 17 of Set 15 | san carlos de bariloche
# Processing Record 18 of Set 15 | ust-maya
# Processing Record 19 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 20 of Set 15 | marzuq
# Processing Record 21 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 22 of Set 15 | nouakchott
# Processing Record 23 of Set 15 | gao
# Processing Record 24 of Set 15 | escanaba
# Processing Record 25 of Set 15 | asekeyevo
# Processing Record 26 of Set 15 | bonthe
# Processing Record 27 of Set 15 | teya
# Processing Record 28 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 15 | evanston
# Processing Record 31 of Set 15 | dir
# Processing Record 32 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 15 | mohanur
# Processing Record 34 of Set 15 | camacha
# Processing Record 35 of Set 15 | obo
# Processing Record 36 of Set 15 | pag
# Processing Record 37 of Set 15 | sinnamary
# Processing Record 38 of Set 15 | carballo
# Processing Record 39 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 15 | adrar
# Processing Record 41 of Set 15 | yialos
# City not found. Skipping...
# Processing Record 42 of Set 15 | bandarbeyla
# Processing Record 43 of Set 15 | papara
# Processing Record 44 of Set 15 | novikovo
# Processing Record 45 of Set 15 | pasighat
# Processing Record 46 of Set 15 | ponta delgada
# Processing Record 47 of Set 15 | wajid
# Processing Record 48 of Set 15 | willowmore
# Processing Record 49 of Set 15 | zabol
# Processing Record 50 of Set 15 | buraydah
# Processing Record 1 of Set 16 | safford
# Processing Record 2 of Set 16 | rassvet
# Processing Record 3 of Set 16 | ntcheu
# Processing Record 4 of Set 16 | lakselv
# Processing Record 5 of Set 16 | cangzhou
# Processing Record 6 of Set 16 | cayenne
# Processing Record 7 of Set 16 | santa fe
# Processing Record 8 of Set 16 | naftah
# City not found. Skipping...
# Processing Record 9 of Set 16 | bantilan
# Processing Record 10 of Set 16 | stornoway
# Processing Record 11 of Set 16 | warangal
# Processing Record 12 of Set 16 | sabha
# Processing Record 13 of Set 16 | kodinsk
# Processing Record 14 of Set 16 | tura
# Processing Record 15 of Set 16 | mahon
# Processing Record 16 of Set 16 | goure
# Processing Record 17 of Set 16 | rio gallegos
# Processing Record 18 of Set 16 | houma
# Processing Record 19 of Set 16 | fuzhou
# Processing Record 20 of Set 16 | barahona
# Processing Record 21 of Set 16 | portoviejo
# Processing Record 22 of Set 16 | parras
# City not found. Skipping...
# Processing Record 23 of Set 16 | ojinaga
# Processing Record 24 of Set 16 | kamenka
# Processing Record 25 of Set 16 | dzerzhinsk
# Processing Record 26 of Set 16 | imphal
# Processing Record 27 of Set 16 | kirkwall
# Processing Record 28 of Set 16 | shahrud
# Processing Record 29 of Set 16 | sadao
# Processing Record 30 of Set 16 | geraldton
# Processing Record 31 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 16 | salur
# Processing Record 33 of Set 16 | anloga
# Processing Record 34 of Set 16 | aripuana
# Processing Record 35 of Set 16 | astorga
# Processing Record 36 of Set 16 | verkhniy avzyan
# Processing Record 37 of Set 16 | lufilufi
# Processing Record 38 of Set 16 | cascais
# Processing Record 39 of Set 16 | vostok
# Processing Record 40 of Set 16 | okato
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 711

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hobart      AU -42.8794  147.3294     59.25        76          79
# 1  San Cristobal      VE   7.7669  -72.2250     86.18        61          25
# 2   Punta Arenas      CL -53.1500  -70.9167     50.11        66           0
# 3   Komsomolskiy      UZ  40.4272   71.7189     70.52        52          48
# 4     Georgetown      MY   5.4112  100.3354     82.33        93          20
# 5         Palora      EC  -1.7000  -77.9333     84.31        52          53
# 6         Avarua      CK -21.2078 -159.7750     78.85        94         100
# 7         Tumaco      CO   1.7986  -78.8156     80.74        81         100
# 8      Busselton      AU -33.6500  115.3333     57.27        85          26
# 9         Nicoya      CR  10.1483  -85.4520     88.63        56         100
#
#    Wind Speed Current Description
# 0        5.75       broken clouds
# 1        6.26    scattered clouds
# 2       13.80           clear sky
# 3        6.91    scattered clouds
# 4        2.30          few clouds
# 5        3.33       broken clouds
# 6        2.30     overcast clouds
# 7        8.61          light rain
# 8        1.23    scattered clouds
# 9        5.44     overcast clouds

# %%
city_data_df.to_csv('WeatherPy_Database.csv', index_label='City_ID')
